# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
#session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

from keras import backend as K

#tf.set_random_seed(seed)
tf.compat.v1.set_random_seed(seed)
#sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)

K.set_session(sess)
#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
from keras.datasets import mnist
from keras.models import Model
from keras.layers import Dense, Input, Flatten, Activation, Dropout, Layer
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical
from keras import optimizers,initializers,constraints,regularizers
from keras import backend as K
from keras.callbacks import LambdaCallback,ModelCheckpoint
from keras.utils import plot_model

from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn import svm
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

import h5py
import math
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse

#--------------------------------------------------------------------------------------------------------------------------------
#Import defined methods
import sys
sys.path.append(r"./Defined")
import Functions as F
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
num_data_used=10000
(x_train_, y_train_), (x_test_, y_test_) = mnist.load_data()
x_data=np.r_[x_train_,x_test_].reshape(70000, 28*28).astype('float32')/255.0
y_data=np.r_[y_train_,y_test_]

np.random.seed(seed)
x_data_num,_=x_data.shape
index=np.arange(x_data_num)
np.random.shuffle(index)

data_arr=x_data[index][0:num_data_used]
label_arr_onehot=y_data[index][0:num_data_used]

C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(data_arr,label_arr_onehot,test_size=0.2,random_state=seed)
x_train,x_validate,y_train_onehot,y_validate_onehot= train_test_split(C_train_x,C_train_y,test_size=0.1,random_state=seed)
x_test=C_test_x
y_test_onehot=C_test_y

print('Shape of x_train: ' + str(x_train.shape)) 
print('Shape of x_validate: ' + str(x_validate.shape)) 
print('Shape of x_test: ' + str(x_test.shape))
print('Shape of y_train: ' + str(y_train_onehot.shape))
print('Shape of y_validate: ' + str(y_validate_onehot.shape))
print('Shape of y_test: ' + str(y_test_onehot.shape))

print('Shape of C_train_x: ' + str(C_train_x.shape)) 
print('Shape of C_train_y: ' + str(C_train_y.shape)) 
print('Shape of C_test_x: ' + str(C_test_x.shape)) 
print('Shape of C_test_y: ' + str(C_test_y.shape)) 

F.show_data_figures(x_train_[0:120],28,28,40)
# Out:
# Shape of x_train: (7200, 784)
# Shape of x_validate: (800, 784)
# Shape of x_test: (2000, 784)
# Shape of y_train: (7200,)
# Shape of y_validate: (800,)
# Shape of y_test: (2000,)
# Shape of C_train_x: (8000, 784)
# Shape of C_train_y: (8000,)
# Shape of C_test_x: (2000, 784)
# Shape of C_test_y: (2000,)

# %%
key_feture_number=50

# %% [markdown]
# # 3.Model

# %%
np.random.seed(seed)

#--------------------------------------------------------------------------------------------------------------------------------
class Feature_Select_Layer(Layer):
    
    def __init__(self, output_dim, l1_lambda, **kwargs):
        super(Feature_Select_Layer, self).__init__(**kwargs)
        self.output_dim = output_dim
        self.l1_lambda=l1_lambda

    def build(self, input_shape):
        self.kernel = self.add_weight(name='kernel',  
                                      shape=(input_shape[1],),
                                      initializer=initializers.RandomUniform(minval=0.999999, maxval=0.9999999, seed=seed),
                                      trainable=True,
                                      regularizer=regularizers.l1(self.l1_lambda),
                                      constraint=constraints.NonNeg())
        super(Feature_Select_Layer, self).build(input_shape)
    
    def call(self, x, selection=False,k=key_feture_number):
        kernel=self.kernel        
        if selection:
            kernel_=K.transpose(kernel)
            kth_largest = tf.math.top_k(kernel_, k=k)[0][-1]
            kernel = tf.where(condition=K.less(kernel,kth_largest),x=K.zeros_like(kernel),y=kernel)        
        return K.dot(x, tf.linalg.tensor_diag(kernel))

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)

#--------------------------------------------------------------------------------------------------------------------------------
def Fractal_Autoencoder(p_data_feature=x_train.shape[1],\
                        p_feture_number=key_feture_number,\
                        p_encoding_dim=key_feture_number,\
                        p_learning_rate=1E-3,\
                        p_l1_lambda=0.1,\
                        p_loss_weight_1=1,\
                        p_loss_weight_2=2,\
                        p_is_use_bias=True):
    
    input_img = Input(shape=(p_data_feature,), name='autoencoder_input')

    feature_selection = Feature_Select_Layer(output_dim=p_data_feature,\
                                             l1_lambda=p_l1_lambda,\
                                             input_shape=(p_data_feature,),\
                                             name='feature_selection')

    feature_selection_score=feature_selection(input_img)
    feature_selection_choose=feature_selection(input_img,selection=True,k=p_feture_number)

    encoded = Dense(p_encoding_dim,\
                    activation='linear',\
                    kernel_initializer=initializers.glorot_uniform(seed),\
                    use_bias=p_is_use_bias,\
                    name='autoencoder_hidden_layer')
    
    encoded_score=encoded(feature_selection_score)
    encoded_choose=encoded(feature_selection_choose)
    
    bottleneck_score=encoded_score
    bottleneck_choose=encoded_choose
    
    decoded = Dense(p_data_feature,\
                    activation='linear',\
                    kernel_initializer=initializers.glorot_uniform(seed),\
                    use_bias=p_is_use_bias,\
                    name='autoencoder_output')
    
    decoded_score =decoded(bottleneck_score)
    decoded_choose =decoded(bottleneck_choose)

    latent_encoder_score = Model(input_img, bottleneck_score)
    latent_encoder_choose = Model(input_img, bottleneck_choose)
    feature_selection_output=Model(input_img,feature_selection_choose)
    autoencoder = Model(input_img, [decoded_score,decoded_choose])
    
    autoencoder.compile(loss=['mean_squared_error','mean_squared_error'],\
                        loss_weights=[p_loss_weight_1, p_loss_weight_2],\
                        optimizer=optimizers.Adam(lr=p_learning_rate))
    
    print('Autoencoder Structure-------------------------------------')
    autoencoder.summary()
    return autoencoder,feature_selection_output,latent_encoder_score,latent_encoder_choose

# %% [markdown]
# ## 3.1 Structure and paramter testing

# %%
epochs_number=1000
batch_size_value=128
is_use_bias=True

# %% [markdown]
# ---
# ### 3.1.1 Fractal Autoencoder
# ---

# %%
F_AE,\
feature_selection_output,\
latent_encoder_score_F_AE,\
latent_encoder_choose_F_AE=Fractal_Autoencoder(p_data_feature=x_train.shape[1],\
                                               p_feture_number=key_feture_number,\
                                               p_encoding_dim=key_feture_number,\
                                               p_learning_rate= 1E-3,\
                                               p_l1_lambda=0.1,\
                                               p_loss_weight_1=1,\
                                               p_loss_weight_2=2,\
                                               p_is_use_bias=is_use_bias)

file_name="./log/F_AE_"+str(key_feture_number)+".png"
plot_model(F_AE, to_file=file_name,show_shapes=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From <ipython-input-4-a331c9891f08>:25: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Autoencoder Structure-------------------------------------
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# autoencoder_input (InputLayer)  (None, 784)          0
# __________________________________________________________________________________________________
# feature_selection (Feature_Sele (None, 784)          784         autoencoder_input[0][0]
#                                                                  autoencoder_input[0][0]
# __________________________________________________________________________________________________
# autoencoder_hidden_layer (Dense (None, 50)           39250       feature_selection[0][0]
#                                                                  feature_selection[1][0]
# __________________________________________________________________________________________________
# autoencoder_output (Dense)      (None, 784)          39984       autoencoder_hidden_layer[0][0]
#                                                                  autoencoder_hidden_layer[1][0]
# ==================================================================================================
# Total params: 80,018
# Trainable params: 80,018
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_checkpoint=ModelCheckpoint('./log_weights/F_AE_'+str(key_feture_number)+'_weights.MNIST{epoch:04d}.hdf5',period=100,save_weights_only=True,verbose=1)

F_AE_history = F_AE.fit(x_train, [x_train,x_train],\
                        epochs=epochs_number,\
                        batch_size=batch_size_value,\
                        shuffle=True,\
                        validation_data=(x_validate, [x_validate,x_validate]),\
                        callbacks=[model_checkpoint])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 7200 samples, validate on 800 samples
# Epoch 1/1000
# 7200/7200 [==============================] - 1s 122us/step - loss: 76.4968 - autoencoder_output_loss: 0.0752 - val_loss: 74.1249 - val_autoencoder_output_loss: 0.0612
# Epoch 2/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 71.9194 - autoencoder_output_loss: 0.0522 - val_loss: 69.5932 - val_autoencoder_output_loss: 0.0470
# Epoch 3/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 67.4143 - autoencoder_output_loss: 0.0422 - val_loss: 65.1042 - val_autoencoder_output_loss: 0.0401
# Epoch 4/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 62.9303 - autoencoder_output_loss: 0.0370 - val_loss: 60.6237 - val_autoencoder_output_loss: 0.0361
# Epoch 5/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 58.4519 - autoencoder_output_loss: 0.0337 - val_loss: 56.1474 - val_autoencoder_output_loss: 0.0334
# Epoch 6/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 53.9771 - autoencoder_output_loss: 0.0316 - val_loss: 51.6738 - val_autoencoder_output_loss: 0.0318
# Epoch 7/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 49.5044 - autoencoder_output_loss: 0.0302 - val_loss: 47.2020 - val_autoencoder_output_loss: 0.0307
# Epoch 8/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 45.0331 - autoencoder_output_loss: 0.0293 - val_loss: 42.7311 - val_autoencoder_output_loss: 0.0300
# Epoch 9/1000
# 7200/7200 [==============================] - 1s 94us/step - loss: 40.5628 - autoencoder_output_loss: 0.0288 - val_loss: 38.2613 - val_autoencoder_output_loss: 0.0295
# Epoch 10/1000
# 7200/7200 [==============================] - 1s 93us/step - loss: 36.0934 - autoencoder_output_loss: 0.0283 - val_loss: 33.7924 - val_autoencoder_output_loss: 0.0292
# Epoch 11/1000
# 7200/7200 [==============================] - 1s 96us/step - loss: 31.6249 - autoencoder_output_loss: 0.0282 - val_loss: 29.3244 - val_autoencoder_output_loss: 0.0292
# Epoch 12/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 27.1576 - autoencoder_output_loss: 0.0282 - val_loss: 24.8579 - val_autoencoder_output_loss: 0.0294
# Epoch 13/1000
# 7200/7200 [==============================] - 1s 102us/step - loss: 22.6920 - autoencoder_output_loss: 0.0285 - val_loss: 20.3934 - val_autoencoder_output_loss: 0.0299
# Epoch 14/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 18.2290 - autoencoder_output_loss: 0.0294 - val_loss: 15.9324 - val_autoencoder_output_loss: 0.0310
# Epoch 15/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 13.7709 - autoencoder_output_loss: 0.0309 - val_loss: 11.4783 - val_autoencoder_output_loss: 0.0331
# Epoch 16/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 9.3230 - autoencoder_output_loss: 0.0339 - val_loss: 7.0397 - val_autoencoder_output_loss: 0.0375
# Epoch 17/1000
# 7200/7200 [==============================] - 1s 102us/step - loss: 4.9004 - autoencoder_output_loss: 0.0405 - val_loss: 2.6422 - val_autoencoder_output_loss: 0.0472
# Epoch 18/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.9332 - autoencoder_output_loss: 0.0543 - val_loss: 0.2156 - val_autoencoder_output_loss: 0.0659
# Epoch 19/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.2041 - autoencoder_output_loss: 0.0666 - val_loss: 0.2070 - val_autoencoder_output_loss: 0.0688
# Epoch 20/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.2026 - autoencoder_output_loss: 0.0674 - val_loss: 0.2071 - val_autoencoder_output_loss: 0.0691
# Epoch 21/1000
# 7200/7200 [==============================] - 1s 96us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2070 - val_autoencoder_output_loss: 0.0691
# Epoch 22/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2069 - val_autoencoder_output_loss: 0.0691
# Epoch 23/1000
# 7200/7200 [==============================] - 1s 107us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2070 - val_autoencoder_output_loss: 0.0691
# Epoch 24/1000
# 7200/7200 [==============================] - 1s 107us/step - loss: 0.2026 - autoencoder_output_loss: 0.0674 - val_loss: 0.2072 - val_autoencoder_output_loss: 0.0692
# Epoch 25/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2069 - val_autoencoder_output_loss: 0.0691
# Epoch 26/1000
# 7200/7200 [==============================] - 1s 84us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2069 - val_autoencoder_output_loss: 0.0691
# Epoch 27/1000
# 7200/7200 [==============================] - 1s 82us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2069 - val_autoencoder_output_loss: 0.0691
# Epoch 28/1000
# 7200/7200 [==============================] - ETA: 0s - loss: 0.2030 - autoencoder_output_loss: 0.067 - 1s 108us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2071 - val_autoencoder_output_loss: 0.0691
# Epoch 29/1000
# 7200/7200 [==============================] - 1s 107us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2069 - val_autoencoder_output_loss: 0.0691
# Epoch 30/1000
# 7200/7200 [==============================] - 1s 102us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2070 - val_autoencoder_output_loss: 0.0691
# Epoch 31/1000
# 7200/7200 [==============================] - 1s 96us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2071 - val_autoencoder_output_loss: 0.0691
# Epoch 32/1000
# 7200/7200 [==============================] - 1s 94us/step - loss: 0.2026 - autoencoder_output_loss: 0.0674 - val_loss: 0.2072 - val_autoencoder_output_loss: 0.0692
# Epoch 33/1000
# 7200/7200 [==============================] - 1s 107us/step - loss: 0.2026 - autoencoder_output_loss: 0.0676 - val_loss: 0.2070 - val_autoencoder_output_loss: 0.0691
# Epoch 34/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2071 - val_autoencoder_output_loss: 0.0691
# Epoch 35/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2072 - val_autoencoder_output_loss: 0.0692
# Epoch 36/1000
# 7200/7200 [==============================] - 1s 104us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2070 - val_autoencoder_output_loss: 0.0691
# Epoch 37/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2068 - val_autoencoder_output_loss: 0.0691
# Epoch 38/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2072 - val_autoencoder_output_loss: 0.0691
# Epoch 39/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2071 - val_autoencoder_output_loss: 0.0692
# Epoch 40/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.2026 - autoencoder_output_loss: 0.0674 - val_loss: 0.2073 - val_autoencoder_output_loss: 0.0692
# Epoch 41/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2070 - val_autoencoder_output_loss: 0.0691
# Epoch 42/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.2027 - autoencoder_output_loss: 0.0674 - val_loss: 0.2070 - val_autoencoder_output_loss: 0.0691
# Epoch 43/1000
# 7200/7200 [==============================] - 1s 92us/step - loss: 0.2026 - autoencoder_output_loss: 0.0674 - val_loss: 0.2070 - val_autoencoder_output_loss: 0.0691
# Epoch 44/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2071 - val_autoencoder_output_loss: 0.0691
# Epoch 45/1000
# 7200/7200 [==============================] - 1s 96us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2069 - val_autoencoder_output_loss: 0.0691
# Epoch 46/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.2026 - autoencoder_output_loss: 0.0674 - val_loss: 0.2070 - val_autoencoder_output_loss: 0.0691
# Epoch 47/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2070 - val_autoencoder_output_loss: 0.0691
# Epoch 48/1000
# 7200/7200 [==============================] - 1s 96us/step - loss: 0.2026 - autoencoder_output_loss: 0.0675 - val_loss: 0.2071 - val_autoencoder_output_loss: 0.0691
# Epoch 49/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.2026 - autoencoder_output_loss: 0.0676 - val_loss: 0.2068 - val_autoencoder_output_loss: 0.0690
# Epoch 50/1000
# 7200/7200 [==============================] - 1s 109us/step - loss: 0.2027 - autoencoder_output_loss: 0.0674 - val_loss: 0.2069 - val_autoencoder_output_loss: 0.0690
# Epoch 51/1000
# 7200/7200 [==============================] - 1s 115us/step - loss: 0.2026 - autoencoder_output_loss: 0.0674 - val_loss: 0.2070 - val_autoencoder_output_loss: 0.0690
# Epoch 52/1000
# 7200/7200 [==============================] - 1s 112us/step - loss: 0.2026 - autoencoder_output_loss: 0.0673 - val_loss: 0.2071 - val_autoencoder_output_loss: 0.0690
# Epoch 53/1000
# 7200/7200 [==============================] - 1s 119us/step - loss: 0.2025 - autoencoder_output_loss: 0.0672 - val_loss: 0.2067 - val_autoencoder_output_loss: 0.0686
# Epoch 54/1000
# 7200/7200 [==============================] - 1s 119us/step - loss: 0.2023 - autoencoder_output_loss: 0.0668 - val_loss: 0.2063 - val_autoencoder_output_loss: 0.0680
# Epoch 55/1000
# 7200/7200 [==============================] - 1s 115us/step - loss: 0.2016 - autoencoder_output_loss: 0.0660 - val_loss: 0.2054 - val_autoencoder_output_loss: 0.0673
# Epoch 56/1000
# 7200/7200 [==============================] - 1s 120us/step - loss: 0.2005 - autoencoder_output_loss: 0.0654 - val_loss: 0.2044 - val_autoencoder_output_loss: 0.0667
# Epoch 57/1000
# 7200/7200 [==============================] - 1s 121us/step - loss: 0.1996 - autoencoder_output_loss: 0.0651 - val_loss: 0.2039 - val_autoencoder_output_loss: 0.0666
# Epoch 58/1000
# 7200/7200 [==============================] - 1s 121us/step - loss: 0.1989 - autoencoder_output_loss: 0.0649 - val_loss: 0.2030 - val_autoencoder_output_loss: 0.0664
# Epoch 59/1000
# 7200/7200 [==============================] - 1s 119us/step - loss: 0.1983 - autoencoder_output_loss: 0.0648 - val_loss: 0.2028 - val_autoencoder_output_loss: 0.0664
# Epoch 60/1000
# 7200/7200 [==============================] - 1s 106us/step - loss: 0.1980 - autoencoder_output_loss: 0.0648 - val_loss: 0.2022 - val_autoencoder_output_loss: 0.0662
# Epoch 61/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.1976 - autoencoder_output_loss: 0.0648 - val_loss: 0.2021 - val_autoencoder_output_loss: 0.0663
# Epoch 62/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.1974 - autoencoder_output_loss: 0.0646 - val_loss: 0.2017 - val_autoencoder_output_loss: 0.0662
# Epoch 63/1000
# 7200/7200 [==============================] - 1s 106us/step - loss: 0.1971 - autoencoder_output_loss: 0.0646 - val_loss: 0.2015 - val_autoencoder_output_loss: 0.0662
# Epoch 64/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1970 - autoencoder_output_loss: 0.0647 - val_loss: 0.2013 - val_autoencoder_output_loss: 0.0662
# Epoch 65/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1968 - autoencoder_output_loss: 0.0647 - val_loss: 0.2014 - val_autoencoder_output_loss: 0.0661
# Epoch 66/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1966 - autoencoder_output_loss: 0.0647 - val_loss: 0.2011 - val_autoencoder_output_loss: 0.0662
# Epoch 67/1000
# 7200/7200 [==============================] - 1s 94us/step - loss: 0.1965 - autoencoder_output_loss: 0.0646 - val_loss: 0.2010 - val_autoencoder_output_loss: 0.0661
# Epoch 68/1000
# 7200/7200 [==============================] - 1s 93us/step - loss: 0.1964 - autoencoder_output_loss: 0.0646 - val_loss: 0.2010 - val_autoencoder_output_loss: 0.0662
# Epoch 69/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1963 - autoencoder_output_loss: 0.0646 - val_loss: 0.2007 - val_autoencoder_output_loss: 0.0662
# Epoch 70/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1962 - autoencoder_output_loss: 0.0645 - val_loss: 0.2006 - val_autoencoder_output_loss: 0.0662
# Epoch 71/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1961 - autoencoder_output_loss: 0.0647 - val_loss: 0.2007 - val_autoencoder_output_loss: 0.0661
# Epoch 72/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1960 - autoencoder_output_loss: 0.0646 - val_loss: 0.2007 - val_autoencoder_output_loss: 0.0662
# Epoch 73/1000
# 7200/7200 [==============================] - 1s 90us/step - loss: 0.1959 - autoencoder_output_loss: 0.0646 - val_loss: 0.2004 - val_autoencoder_output_loss: 0.0661
# Epoch 74/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1959 - autoencoder_output_loss: 0.0646 - val_loss: 0.2004 - val_autoencoder_output_loss: 0.0661
# Epoch 75/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1959 - autoencoder_output_loss: 0.0646 - val_loss: 0.2005 - val_autoencoder_output_loss: 0.0661
# Epoch 76/1000
# 7200/7200 [==============================] - 1s 95us/step - loss: 0.1958 - autoencoder_output_loss: 0.0646 - val_loss: 0.2003 - val_autoencoder_output_loss: 0.0661
# Epoch 77/1000
# 7200/7200 [==============================] - 1s 101us/step - loss: 0.1958 - autoencoder_output_loss: 0.0646 - val_loss: 0.2005 - val_autoencoder_output_loss: 0.0662
# Epoch 78/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1957 - autoencoder_output_loss: 0.0646 - val_loss: 0.2002 - val_autoencoder_output_loss: 0.0660
# Epoch 79/1000
# 7200/7200 [==============================] - 1s 96us/step - loss: 0.1956 - autoencoder_output_loss: 0.0646 - val_loss: 0.2002 - val_autoencoder_output_loss: 0.0661
# Epoch 80/1000
# 7200/7200 [==============================] - 1s 93us/step - loss: 0.1956 - autoencoder_output_loss: 0.0645 - val_loss: 0.2000 - val_autoencoder_output_loss: 0.0661
# Epoch 81/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1955 - autoencoder_output_loss: 0.0645 - val_loss: 0.1998 - val_autoencoder_output_loss: 0.0661
# Epoch 82/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1955 - autoencoder_output_loss: 0.0646 - val_loss: 0.1999 - val_autoencoder_output_loss: 0.0661
# Epoch 83/1000
# 7200/7200 [==============================] - 1s 93us/step - loss: 0.1954 - autoencoder_output_loss: 0.0645 - val_loss: 0.2001 - val_autoencoder_output_loss: 0.0662
# Epoch 84/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1954 - autoencoder_output_loss: 0.0646 - val_loss: 0.2001 - val_autoencoder_output_loss: 0.0662
# Epoch 85/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1953 - autoencoder_output_loss: 0.0646 - val_loss: 0.1997 - val_autoencoder_output_loss: 0.0661
# Epoch 86/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1953 - autoencoder_output_loss: 0.0646 - val_loss: 0.2000 - val_autoencoder_output_loss: 0.0661
# Epoch 87/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1953 - autoencoder_output_loss: 0.0646 - val_loss: 0.1998 - val_autoencoder_output_loss: 0.0660
# Epoch 88/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1953 - autoencoder_output_loss: 0.0646 - val_loss: 0.1998 - val_autoencoder_output_loss: 0.0660
# Epoch 89/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1954 - autoencoder_output_loss: 0.0645 - val_loss: 0.1997 - val_autoencoder_output_loss: 0.0659
# Epoch 90/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1951 - autoencoder_output_loss: 0.0643 - val_loss: 0.1993 - val_autoencoder_output_loss: 0.0654
# Epoch 91/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1944 - autoencoder_output_loss: 0.0636 - val_loss: 0.1981 - val_autoencoder_output_loss: 0.0646
# Epoch 92/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1932 - autoencoder_output_loss: 0.0629 - val_loss: 0.1966 - val_autoencoder_output_loss: 0.0641
# Epoch 93/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1921 - autoencoder_output_loss: 0.0625 - val_loss: 0.1955 - val_autoencoder_output_loss: 0.0636
# Epoch 94/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1912 - autoencoder_output_loss: 0.0621 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0632
# Epoch 95/1000
# 7200/7200 [==============================] - 1s 91us/step - loss: 0.1905 - autoencoder_output_loss: 0.0619 - val_loss: 0.1941 - val_autoencoder_output_loss: 0.0631
# Epoch 96/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1900 - autoencoder_output_loss: 0.0616 - val_loss: 0.1934 - val_autoencoder_output_loss: 0.0628
# Epoch 97/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.1895 - autoencoder_output_loss: 0.0615 - val_loss: 0.1928 - val_autoencoder_output_loss: 0.0626
# Epoch 98/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.1890 - autoencoder_output_loss: 0.0614 - val_loss: 0.1923 - val_autoencoder_output_loss: 0.0624
# Epoch 99/1000
# 7200/7200 [==============================] - 1s 87us/step - loss: 0.1886 - autoencoder_output_loss: 0.0612 - val_loss: 0.1918 - val_autoencoder_output_loss: 0.0623
# Epoch 100/1000
# 7200/7200 [==============================] - 1s 90us/step - loss: 0.1881 - autoencoder_output_loss: 0.0611 - val_loss: 0.1913 - val_autoencoder_output_loss: 0.0621
#
# Epoch 00100: saving model to ./log_weights/F_AE_50_weights.MNIST0100.hdf5
# Epoch 101/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1877 - autoencoder_output_loss: 0.0610 - val_loss: 0.1911 - val_autoencoder_output_loss: 0.0620
# Epoch 102/1000
# 7200/7200 [==============================] - 1s 94us/step - loss: 0.1874 - autoencoder_output_loss: 0.0609 - val_loss: 0.1905 - val_autoencoder_output_loss: 0.0620
# Epoch 103/1000
# 7200/7200 [==============================] - 1s 93us/step - loss: 0.1870 - autoencoder_output_loss: 0.0608 - val_loss: 0.1903 - val_autoencoder_output_loss: 0.0619
# Epoch 104/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1867 - autoencoder_output_loss: 0.0607 - val_loss: 0.1899 - val_autoencoder_output_loss: 0.0618
# Epoch 105/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1864 - autoencoder_output_loss: 0.0605 - val_loss: 0.1895 - val_autoencoder_output_loss: 0.0617
# Epoch 106/1000
# 7200/7200 [==============================] - 1s 104us/step - loss: 0.1860 - autoencoder_output_loss: 0.0605 - val_loss: 0.1894 - val_autoencoder_output_loss: 0.0616
# Epoch 107/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1858 - autoencoder_output_loss: 0.0604 - val_loss: 0.1893 - val_autoencoder_output_loss: 0.0617
# Epoch 108/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.1856 - autoencoder_output_loss: 0.0604 - val_loss: 0.1887 - val_autoencoder_output_loss: 0.0615
# Epoch 109/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.1853 - autoencoder_output_loss: 0.0602 - val_loss: 0.1886 - val_autoencoder_output_loss: 0.0614
# Epoch 110/1000
# 7200/7200 [==============================] - 1s 109us/step - loss: 0.1852 - autoencoder_output_loss: 0.0602 - val_loss: 0.1884 - val_autoencoder_output_loss: 0.0613
# Epoch 111/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1850 - autoencoder_output_loss: 0.0601 - val_loss: 0.1883 - val_autoencoder_output_loss: 0.0614
# Epoch 112/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1848 - autoencoder_output_loss: 0.0601 - val_loss: 0.1880 - val_autoencoder_output_loss: 0.0613
# Epoch 113/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1846 - autoencoder_output_loss: 0.0601 - val_loss: 0.1877 - val_autoencoder_output_loss: 0.0612
# Epoch 114/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1844 - autoencoder_output_loss: 0.0600 - val_loss: 0.1877 - val_autoencoder_output_loss: 0.0610
# Epoch 115/1000
# 7200/7200 [==============================] - 1s 96us/step - loss: 0.1839 - autoencoder_output_loss: 0.0597 - val_loss: 0.1869 - val_autoencoder_output_loss: 0.0606
# Epoch 116/1000
# 7200/7200 [==============================] - 1s 93us/step - loss: 0.1835 - autoencoder_output_loss: 0.0595 - val_loss: 0.1864 - val_autoencoder_output_loss: 0.0603
# Epoch 117/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1830 - autoencoder_output_loss: 0.0589 - val_loss: 0.1854 - val_autoencoder_output_loss: 0.0597
# Epoch 118/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1818 - autoencoder_output_loss: 0.0581 - val_loss: 0.1841 - val_autoencoder_output_loss: 0.0589
# Epoch 119/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1805 - autoencoder_output_loss: 0.0575 - val_loss: 0.1826 - val_autoencoder_output_loss: 0.0581
# Epoch 120/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1793 - autoencoder_output_loss: 0.0569 - val_loss: 0.1810 - val_autoencoder_output_loss: 0.0577
# Epoch 121/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1780 - autoencoder_output_loss: 0.0565 - val_loss: 0.1802 - val_autoencoder_output_loss: 0.0573
# Epoch 122/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1768 - autoencoder_output_loss: 0.0560 - val_loss: 0.1787 - val_autoencoder_output_loss: 0.0567
# Epoch 123/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1759 - autoencoder_output_loss: 0.0556 - val_loss: 0.1777 - val_autoencoder_output_loss: 0.0566
# Epoch 124/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1748 - autoencoder_output_loss: 0.0553 - val_loss: 0.1770 - val_autoencoder_output_loss: 0.0563
# Epoch 125/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1740 - autoencoder_output_loss: 0.0549 - val_loss: 0.1762 - val_autoencoder_output_loss: 0.0558
# Epoch 126/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1732 - autoencoder_output_loss: 0.0546 - val_loss: 0.1753 - val_autoencoder_output_loss: 0.0553
# Epoch 127/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1722 - autoencoder_output_loss: 0.0542 - val_loss: 0.1742 - val_autoencoder_output_loss: 0.0550
# Epoch 128/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1715 - autoencoder_output_loss: 0.0539 - val_loss: 0.1735 - val_autoencoder_output_loss: 0.0549
# Epoch 129/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1706 - autoencoder_output_loss: 0.0537 - val_loss: 0.1730 - val_autoencoder_output_loss: 0.0550
# Epoch 130/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1701 - autoencoder_output_loss: 0.0535 - val_loss: 0.1722 - val_autoencoder_output_loss: 0.0546
# Epoch 131/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1694 - autoencoder_output_loss: 0.0534 - val_loss: 0.1717 - val_autoencoder_output_loss: 0.0545
# Epoch 132/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1689 - autoencoder_output_loss: 0.0533 - val_loss: 0.1714 - val_autoencoder_output_loss: 0.0544
# Epoch 133/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1685 - autoencoder_output_loss: 0.0532 - val_loss: 0.1708 - val_autoencoder_output_loss: 0.0541
# Epoch 134/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.1680 - autoencoder_output_loss: 0.0531 - val_loss: 0.1708 - val_autoencoder_output_loss: 0.0541
# Epoch 135/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1677 - autoencoder_output_loss: 0.0530 - val_loss: 0.1698 - val_autoencoder_output_loss: 0.0541
# Epoch 136/1000
# 7200/7200 [==============================] - 1s 104us/step - loss: 0.1673 - autoencoder_output_loss: 0.0529 - val_loss: 0.1697 - val_autoencoder_output_loss: 0.0539
# Epoch 137/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1667 - autoencoder_output_loss: 0.0524 - val_loss: 0.1687 - val_autoencoder_output_loss: 0.0532
# Epoch 138/1000
# 7200/7200 [==============================] - 1s 101us/step - loss: 0.1655 - autoencoder_output_loss: 0.0517 - val_loss: 0.1674 - val_autoencoder_output_loss: 0.0526
# Epoch 139/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1645 - autoencoder_output_loss: 0.0512 - val_loss: 0.1664 - val_autoencoder_output_loss: 0.0522
# Epoch 140/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1635 - autoencoder_output_loss: 0.0509 - val_loss: 0.1653 - val_autoencoder_output_loss: 0.0517
# Epoch 141/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.1627 - autoencoder_output_loss: 0.0506 - val_loss: 0.1647 - val_autoencoder_output_loss: 0.0515
# Epoch 142/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.1620 - autoencoder_output_loss: 0.0503 - val_loss: 0.1639 - val_autoencoder_output_loss: 0.0511
# Epoch 143/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1610 - autoencoder_output_loss: 0.0499 - val_loss: 0.1626 - val_autoencoder_output_loss: 0.0506
# Epoch 144/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.1600 - autoencoder_output_loss: 0.0495 - val_loss: 0.1615 - val_autoencoder_output_loss: 0.0503
# Epoch 145/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1591 - autoencoder_output_loss: 0.0491 - val_loss: 0.1609 - val_autoencoder_output_loss: 0.0500
# Epoch 146/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1580 - autoencoder_output_loss: 0.0486 - val_loss: 0.1603 - val_autoencoder_output_loss: 0.0494
# Epoch 147/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1570 - autoencoder_output_loss: 0.0481 - val_loss: 0.1583 - val_autoencoder_output_loss: 0.0490
# Epoch 148/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1558 - autoencoder_output_loss: 0.0478 - val_loss: 0.1573 - val_autoencoder_output_loss: 0.0486
# Epoch 149/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1550 - autoencoder_output_loss: 0.0473 - val_loss: 0.1565 - val_autoencoder_output_loss: 0.0482
# Epoch 150/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1538 - autoencoder_output_loss: 0.0469 - val_loss: 0.1553 - val_autoencoder_output_loss: 0.0476
# Epoch 151/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1527 - autoencoder_output_loss: 0.0464 - val_loss: 0.1544 - val_autoencoder_output_loss: 0.0473
# Epoch 152/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1518 - autoencoder_output_loss: 0.0460 - val_loss: 0.1535 - val_autoencoder_output_loss: 0.0467
# Epoch 153/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1508 - autoencoder_output_loss: 0.0456 - val_loss: 0.1522 - val_autoencoder_output_loss: 0.0464
# Epoch 154/1000
# 7200/7200 [==============================] - 1s 96us/step - loss: 0.1497 - autoencoder_output_loss: 0.0452 - val_loss: 0.1512 - val_autoencoder_output_loss: 0.0460
# Epoch 155/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1487 - autoencoder_output_loss: 0.0448 - val_loss: 0.1503 - val_autoencoder_output_loss: 0.0455
# Epoch 156/1000
# 7200/7200 [==============================] - 1s 96us/step - loss: 0.1476 - autoencoder_output_loss: 0.0443 - val_loss: 0.1494 - val_autoencoder_output_loss: 0.0451
# Epoch 157/1000
# 7200/7200 [==============================] - 1s 95us/step - loss: 0.1467 - autoencoder_output_loss: 0.0440 - val_loss: 0.1479 - val_autoencoder_output_loss: 0.0447
# Epoch 158/1000
# 7200/7200 [==============================] - 1s 91us/step - loss: 0.1456 - autoencoder_output_loss: 0.0435 - val_loss: 0.1473 - val_autoencoder_output_loss: 0.0445
# Epoch 159/1000
# 7200/7200 [==============================] - 1s 90us/step - loss: 0.1446 - autoencoder_output_loss: 0.0431 - val_loss: 0.1461 - val_autoencoder_output_loss: 0.0440
# Epoch 160/1000
# 7200/7200 [==============================] - 1s 91us/step - loss: 0.1437 - autoencoder_output_loss: 0.0429 - val_loss: 0.1451 - val_autoencoder_output_loss: 0.0438
# Epoch 161/1000
# 7200/7200 [==============================] - 1s 91us/step - loss: 0.1428 - autoencoder_output_loss: 0.0425 - val_loss: 0.1443 - val_autoencoder_output_loss: 0.0434
# Epoch 162/1000
# 7200/7200 [==============================] - 1s 96us/step - loss: 0.1418 - autoencoder_output_loss: 0.0421 - val_loss: 0.1431 - val_autoencoder_output_loss: 0.0428
# Epoch 163/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1407 - autoencoder_output_loss: 0.0417 - val_loss: 0.1420 - val_autoencoder_output_loss: 0.0424
# Epoch 164/1000
# 7200/7200 [==============================] - 1s 102us/step - loss: 0.1398 - autoencoder_output_loss: 0.0412 - val_loss: 0.1411 - val_autoencoder_output_loss: 0.0421
# Epoch 165/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1387 - autoencoder_output_loss: 0.0409 - val_loss: 0.1402 - val_autoencoder_output_loss: 0.0416
# Epoch 166/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1377 - autoencoder_output_loss: 0.0404 - val_loss: 0.1388 - val_autoencoder_output_loss: 0.0410
# Epoch 167/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1366 - autoencoder_output_loss: 0.0401 - val_loss: 0.1383 - val_autoencoder_output_loss: 0.0410
# Epoch 168/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1358 - autoencoder_output_loss: 0.0398 - val_loss: 0.1368 - val_autoencoder_output_loss: 0.0405
# Epoch 169/1000
# 7200/7200 [==============================] - 1s 90us/step - loss: 0.1347 - autoencoder_output_loss: 0.0394 - val_loss: 0.1360 - val_autoencoder_output_loss: 0.0402
# Epoch 170/1000
# 7200/7200 [==============================] - 1s 94us/step - loss: 0.1339 - autoencoder_output_loss: 0.0392 - val_loss: 0.1350 - val_autoencoder_output_loss: 0.0399
# Epoch 171/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1330 - autoencoder_output_loss: 0.0389 - val_loss: 0.1344 - val_autoencoder_output_loss: 0.0397
# Epoch 172/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1323 - autoencoder_output_loss: 0.0386 - val_loss: 0.1337 - val_autoencoder_output_loss: 0.0395
# Epoch 173/1000
# 7200/7200 [==============================] - 1s 96us/step - loss: 0.1316 - autoencoder_output_loss: 0.0384 - val_loss: 0.1325 - val_autoencoder_output_loss: 0.0390
# Epoch 174/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1307 - autoencoder_output_loss: 0.0381 - val_loss: 0.1318 - val_autoencoder_output_loss: 0.0387
# Epoch 175/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1298 - autoencoder_output_loss: 0.0378 - val_loss: 0.1307 - val_autoencoder_output_loss: 0.0384
# Epoch 176/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1290 - autoencoder_output_loss: 0.0376 - val_loss: 0.1302 - val_autoencoder_output_loss: 0.0381
# Epoch 177/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.1283 - autoencoder_output_loss: 0.0374 - val_loss: 0.1293 - val_autoencoder_output_loss: 0.0378
# Epoch 178/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1275 - autoencoder_output_loss: 0.0371 - val_loss: 0.1291 - val_autoencoder_output_loss: 0.0380
# Epoch 179/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1270 - autoencoder_output_loss: 0.0370 - val_loss: 0.1280 - val_autoencoder_output_loss: 0.0374
# Epoch 180/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1263 - autoencoder_output_loss: 0.0367 - val_loss: 0.1275 - val_autoencoder_output_loss: 0.0374
# Epoch 181/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1258 - autoencoder_output_loss: 0.0366 - val_loss: 0.1267 - val_autoencoder_output_loss: 0.0372
# Epoch 182/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1251 - autoencoder_output_loss: 0.0364 - val_loss: 0.1260 - val_autoencoder_output_loss: 0.0369
# Epoch 183/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1245 - autoencoder_output_loss: 0.0362 - val_loss: 0.1253 - val_autoencoder_output_loss: 0.0368
# Epoch 184/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1239 - autoencoder_output_loss: 0.0359 - val_loss: 0.1247 - val_autoencoder_output_loss: 0.0365
# Epoch 185/1000
# 7200/7200 [==============================] - 1s 93us/step - loss: 0.1233 - autoencoder_output_loss: 0.0358 - val_loss: 0.1242 - val_autoencoder_output_loss: 0.0363
# Epoch 186/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1228 - autoencoder_output_loss: 0.0357 - val_loss: 0.1237 - val_autoencoder_output_loss: 0.0363
# Epoch 187/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.1223 - autoencoder_output_loss: 0.0355 - val_loss: 0.1231 - val_autoencoder_output_loss: 0.0361
# Epoch 188/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1217 - autoencoder_output_loss: 0.0354 - val_loss: 0.1228 - val_autoencoder_output_loss: 0.0358
# Epoch 189/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1213 - autoencoder_output_loss: 0.0351 - val_loss: 0.1226 - val_autoencoder_output_loss: 0.0356
# Epoch 190/1000
# 7200/7200 [==============================] - 1s 107us/step - loss: 0.1206 - autoencoder_output_loss: 0.0349 - val_loss: 0.1218 - val_autoencoder_output_loss: 0.0354
# Epoch 191/1000
# 7200/7200 [==============================] - 1s 108us/step - loss: 0.1200 - autoencoder_output_loss: 0.0347 - val_loss: 0.1210 - val_autoencoder_output_loss: 0.0351
# Epoch 192/1000
# 7200/7200 [==============================] - 1s 107us/step - loss: 0.1194 - autoencoder_output_loss: 0.0344 - val_loss: 0.1204 - val_autoencoder_output_loss: 0.0349
# Epoch 193/1000
# 7200/7200 [==============================] - 1s 105us/step - loss: 0.1187 - autoencoder_output_loss: 0.0341 - val_loss: 0.1198 - val_autoencoder_output_loss: 0.0347
# Epoch 194/1000
# 7200/7200 [==============================] - 1s 108us/step - loss: 0.1180 - autoencoder_output_loss: 0.0338 - val_loss: 0.1189 - val_autoencoder_output_loss: 0.0342
# Epoch 195/1000
# 7200/7200 [==============================] - 1s 104us/step - loss: 0.1173 - autoencoder_output_loss: 0.0336 - val_loss: 0.1182 - val_autoencoder_output_loss: 0.0341
# Epoch 196/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.1166 - autoencoder_output_loss: 0.0334 - val_loss: 0.1181 - val_autoencoder_output_loss: 0.0338
# Epoch 197/1000
# 7200/7200 [==============================] - 1s 104us/step - loss: 0.1162 - autoencoder_output_loss: 0.0333 - val_loss: 0.1172 - val_autoencoder_output_loss: 0.0337
# Epoch 198/1000
# 7200/7200 [==============================] - 1s 105us/step - loss: 0.1156 - autoencoder_output_loss: 0.0331 - val_loss: 0.1167 - val_autoencoder_output_loss: 0.0336
# Epoch 199/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.1151 - autoencoder_output_loss: 0.0329 - val_loss: 0.1160 - val_autoencoder_output_loss: 0.0334
# Epoch 200/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1144 - autoencoder_output_loss: 0.0327 - val_loss: 0.1157 - val_autoencoder_output_loss: 0.0333
#
# Epoch 00200: saving model to ./log_weights/F_AE_50_weights.MNIST0200.hdf5
# Epoch 201/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.1140 - autoencoder_output_loss: 0.0326 - val_loss: 0.1152 - val_autoencoder_output_loss: 0.0332
# Epoch 202/1000
# 7200/7200 [==============================] - 1s 102us/step - loss: 0.1135 - autoencoder_output_loss: 0.0325 - val_loss: 0.1149 - val_autoencoder_output_loss: 0.0331
# Epoch 203/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.1130 - autoencoder_output_loss: 0.0324 - val_loss: 0.1141 - val_autoencoder_output_loss: 0.0330
# Epoch 204/1000
# 7200/7200 [==============================] - 1s 102us/step - loss: 0.1125 - autoencoder_output_loss: 0.0322 - val_loss: 0.1135 - val_autoencoder_output_loss: 0.0327
# Epoch 205/1000
# 7200/7200 [==============================] - 1s 112us/step - loss: 0.1120 - autoencoder_output_loss: 0.0320 - val_loss: 0.1133 - val_autoencoder_output_loss: 0.0327
# Epoch 206/1000
# 7200/7200 [==============================] - 1s 110us/step - loss: 0.1114 - autoencoder_output_loss: 0.0318 - val_loss: 0.1126 - val_autoencoder_output_loss: 0.0324
# Epoch 207/1000
# 7200/7200 [==============================] - 1s 113us/step - loss: 0.1110 - autoencoder_output_loss: 0.0317 - val_loss: 0.1120 - val_autoencoder_output_loss: 0.0322
# Epoch 208/1000
# 7200/7200 [==============================] - 1s 106us/step - loss: 0.1105 - autoencoder_output_loss: 0.0316 - val_loss: 0.1119 - val_autoencoder_output_loss: 0.0321
# Epoch 209/1000
# 7200/7200 [==============================] - 1s 101us/step - loss: 0.1100 - autoencoder_output_loss: 0.0314 - val_loss: 0.1115 - val_autoencoder_output_loss: 0.0320
# Epoch 210/1000
# 7200/7200 [==============================] - 1s 101us/step - loss: 0.1096 - autoencoder_output_loss: 0.0312 - val_loss: 0.1107 - val_autoencoder_output_loss: 0.0317
# Epoch 211/1000
# 7200/7200 [==============================] - 1s 101us/step - loss: 0.1091 - autoencoder_output_loss: 0.0311 - val_loss: 0.1102 - val_autoencoder_output_loss: 0.0317
# Epoch 212/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1085 - autoencoder_output_loss: 0.0309 - val_loss: 0.1101 - val_autoencoder_output_loss: 0.0316
# Epoch 213/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1082 - autoencoder_output_loss: 0.0308 - val_loss: 0.1095 - val_autoencoder_output_loss: 0.0315
# Epoch 214/1000
# 7200/7200 [==============================] - 1s 96us/step - loss: 0.1078 - autoencoder_output_loss: 0.0307 - val_loss: 0.1093 - val_autoencoder_output_loss: 0.0315
# Epoch 215/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1073 - autoencoder_output_loss: 0.0305 - val_loss: 0.1087 - val_autoencoder_output_loss: 0.0311
# Epoch 216/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1068 - autoencoder_output_loss: 0.0303 - val_loss: 0.1083 - val_autoencoder_output_loss: 0.0311
# Epoch 217/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.1063 - autoencoder_output_loss: 0.0302 - val_loss: 0.1079 - val_autoencoder_output_loss: 0.0308
# Epoch 218/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1060 - autoencoder_output_loss: 0.0302 - val_loss: 0.1073 - val_autoencoder_output_loss: 0.0307
# Epoch 219/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.1055 - autoencoder_output_loss: 0.0300 - val_loss: 0.1072 - val_autoencoder_output_loss: 0.0307
# Epoch 220/1000
# 7200/7200 [==============================] - 1s 101us/step - loss: 0.1052 - autoencoder_output_loss: 0.0299 - val_loss: 0.1065 - val_autoencoder_output_loss: 0.0305
# Epoch 221/1000
# 7200/7200 [==============================] - 1s 106us/step - loss: 0.1047 - autoencoder_output_loss: 0.0298 - val_loss: 0.1063 - val_autoencoder_output_loss: 0.0305
# Epoch 222/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.1044 - autoencoder_output_loss: 0.0297 - val_loss: 0.1061 - val_autoencoder_output_loss: 0.0306
# Epoch 223/1000
# 7200/7200 [==============================] - 1s 101us/step - loss: 0.1040 - autoencoder_output_loss: 0.0296 - val_loss: 0.1054 - val_autoencoder_output_loss: 0.0303
# Epoch 224/1000
# 7200/7200 [==============================] - 1s 104us/step - loss: 0.1037 - autoencoder_output_loss: 0.0295 - val_loss: 0.1052 - val_autoencoder_output_loss: 0.0304
# Epoch 225/1000
# 7200/7200 [==============================] - 1s 102us/step - loss: 0.1033 - autoencoder_output_loss: 0.0294 - val_loss: 0.1048 - val_autoencoder_output_loss: 0.0302
# Epoch 226/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.1031 - autoencoder_output_loss: 0.0293 - val_loss: 0.1043 - val_autoencoder_output_loss: 0.0299
# Epoch 227/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.1027 - autoencoder_output_loss: 0.0292 - val_loss: 0.1041 - val_autoencoder_output_loss: 0.0299
# Epoch 228/1000
# 7200/7200 [==============================] - 1s 105us/step - loss: 0.1022 - autoencoder_output_loss: 0.0291 - val_loss: 0.1037 - val_autoencoder_output_loss: 0.0298
# Epoch 229/1000
# 7200/7200 [==============================] - 1s 110us/step - loss: 0.1019 - autoencoder_output_loss: 0.0290 - val_loss: 0.1039 - val_autoencoder_output_loss: 0.0299
# Epoch 230/1000
# 7200/7200 [==============================] - 1s 108us/step - loss: 0.1017 - autoencoder_output_loss: 0.0290 - val_loss: 0.1032 - val_autoencoder_output_loss: 0.0296
# Epoch 231/1000
# 7200/7200 [==============================] - 1s 110us/step - loss: 0.1013 - autoencoder_output_loss: 0.0288 - val_loss: 0.1031 - val_autoencoder_output_loss: 0.0296
# Epoch 232/1000
# 7200/7200 [==============================] - 1s 108us/step - loss: 0.1010 - autoencoder_output_loss: 0.0287 - val_loss: 0.1026 - val_autoencoder_output_loss: 0.0294
# Epoch 233/1000
# 7200/7200 [==============================] - 1s 109us/step - loss: 0.1006 - autoencoder_output_loss: 0.0286 - val_loss: 0.1024 - val_autoencoder_output_loss: 0.0293
# Epoch 234/1000
# 7200/7200 [==============================] - 1s 105us/step - loss: 0.1002 - autoencoder_output_loss: 0.0284 - val_loss: 0.1019 - val_autoencoder_output_loss: 0.0293
# Epoch 235/1000
# 7200/7200 [==============================] - 1s 109us/step - loss: 0.1000 - autoencoder_output_loss: 0.0284 - val_loss: 0.1015 - val_autoencoder_output_loss: 0.0290
# Epoch 236/1000
# 7200/7200 [==============================] - 1s 109us/step - loss: 0.0996 - autoencoder_output_loss: 0.0282 - val_loss: 0.1013 - val_autoencoder_output_loss: 0.0289
# Epoch 237/1000
# 7200/7200 [==============================] - 1s 109us/step - loss: 0.0992 - autoencoder_output_loss: 0.0281 - val_loss: 0.1008 - val_autoencoder_output_loss: 0.0290
# Epoch 238/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.0989 - autoencoder_output_loss: 0.0280 - val_loss: 0.1005 - val_autoencoder_output_loss: 0.0289
# Epoch 239/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.0987 - autoencoder_output_loss: 0.0280 - val_loss: 0.1001 - val_autoencoder_output_loss: 0.0286
# Epoch 240/1000
# 7200/7200 [==============================] - 1s 102us/step - loss: 0.0983 - autoencoder_output_loss: 0.0278 - val_loss: 0.0997 - val_autoencoder_output_loss: 0.0285
# Epoch 241/1000
# 7200/7200 [==============================] - 1s 104us/step - loss: 0.0979 - autoencoder_output_loss: 0.0278 - val_loss: 0.0996 - val_autoencoder_output_loss: 0.0285
# Epoch 242/1000
# 7200/7200 [==============================] - 1s 108us/step - loss: 0.0976 - autoencoder_output_loss: 0.0277 - val_loss: 0.0993 - val_autoencoder_output_loss: 0.0285
# Epoch 243/1000
# 7200/7200 [==============================] - 1s 107us/step - loss: 0.0974 - autoencoder_output_loss: 0.0275 - val_loss: 0.0993 - val_autoencoder_output_loss: 0.0283
# Epoch 244/1000
# 7200/7200 [==============================] - 1s 108us/step - loss: 0.0970 - autoencoder_output_loss: 0.0275 - val_loss: 0.0988 - val_autoencoder_output_loss: 0.0283
# Epoch 245/1000
# 7200/7200 [==============================] - 1s 114us/step - loss: 0.0968 - autoencoder_output_loss: 0.0274 - val_loss: 0.0985 - val_autoencoder_output_loss: 0.0283
# Epoch 246/1000
# 7200/7200 [==============================] - 1s 109us/step - loss: 0.0967 - autoencoder_output_loss: 0.0274 - val_loss: 0.0981 - val_autoencoder_output_loss: 0.0281
# Epoch 247/1000
# 7200/7200 [==============================] - 1s 111us/step - loss: 0.0963 - autoencoder_output_loss: 0.0273 - val_loss: 0.0978 - val_autoencoder_output_loss: 0.0280
# Epoch 248/1000
# 7200/7200 [==============================] - 1s 108us/step - loss: 0.0959 - autoencoder_output_loss: 0.0272 - val_loss: 0.0976 - val_autoencoder_output_loss: 0.0277
# Epoch 249/1000
# 7200/7200 [==============================] - 1s 101us/step - loss: 0.0957 - autoencoder_output_loss: 0.0270 - val_loss: 0.0976 - val_autoencoder_output_loss: 0.0279
# Epoch 250/1000
# 7200/7200 [==============================] - 1s 105us/step - loss: 0.0954 - autoencoder_output_loss: 0.0270 - val_loss: 0.0970 - val_autoencoder_output_loss: 0.0277
# Epoch 251/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.0950 - autoencoder_output_loss: 0.0268 - val_loss: 0.0969 - val_autoencoder_output_loss: 0.0276
# Epoch 252/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.0947 - autoencoder_output_loss: 0.0267 - val_loss: 0.0962 - val_autoencoder_output_loss: 0.0275
# Epoch 253/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.0944 - autoencoder_output_loss: 0.0265 - val_loss: 0.0962 - val_autoencoder_output_loss: 0.0274
# Epoch 254/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.0940 - autoencoder_output_loss: 0.0264 - val_loss: 0.0961 - val_autoencoder_output_loss: 0.0274
# Epoch 255/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.0938 - autoencoder_output_loss: 0.0264 - val_loss: 0.0961 - val_autoencoder_output_loss: 0.0274
# Epoch 256/1000
# 7200/7200 [==============================] - 1s 104us/step - loss: 0.0935 - autoencoder_output_loss: 0.0263 - val_loss: 0.0953 - val_autoencoder_output_loss: 0.0272
# Epoch 257/1000
# 7200/7200 [==============================] - 1s 101us/step - loss: 0.0932 - autoencoder_output_loss: 0.0262 - val_loss: 0.0948 - val_autoencoder_output_loss: 0.0268
# Epoch 258/1000
# 7200/7200 [==============================] - 1s 102us/step - loss: 0.0929 - autoencoder_output_loss: 0.0261 - val_loss: 0.0947 - val_autoencoder_output_loss: 0.0271
# Epoch 259/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.0926 - autoencoder_output_loss: 0.0261 - val_loss: 0.0943 - val_autoencoder_output_loss: 0.0269
# Epoch 260/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.0924 - autoencoder_output_loss: 0.0260 - val_loss: 0.0942 - val_autoencoder_output_loss: 0.0268
# Epoch 261/1000
# 7200/7200 [==============================] - 1s 104us/step - loss: 0.0922 - autoencoder_output_loss: 0.0259 - val_loss: 0.0939 - val_autoencoder_output_loss: 0.0269
# Epoch 262/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.0918 - autoencoder_output_loss: 0.0259 - val_loss: 0.0938 - val_autoencoder_output_loss: 0.0268
# Epoch 263/1000
# 7200/7200 [==============================] - 1s 104us/step - loss: 0.0916 - autoencoder_output_loss: 0.0258 - val_loss: 0.0931 - val_autoencoder_output_loss: 0.0266
# Epoch 264/1000
# 7200/7200 [==============================] - 1s 102us/step - loss: 0.0914 - autoencoder_output_loss: 0.0258 - val_loss: 0.0933 - val_autoencoder_output_loss: 0.0266
# Epoch 265/1000
# 7200/7200 [==============================] - 1s 107us/step - loss: 0.0912 - autoencoder_output_loss: 0.0257 - val_loss: 0.0929 - val_autoencoder_output_loss: 0.0265
# Epoch 266/1000
# ...
# Epoch 913/1000
# 7200/7200 [==============================] - 1s 92us/step - loss: 0.0632 - autoencoder_output_loss: 0.0193 - val_loss: 0.0652 - val_autoencoder_output_loss: 0.0201
# Epoch 914/1000
# 7200/7200 [==============================] - 1s 94us/step - loss: 0.0633 - autoencoder_output_loss: 0.0194 - val_loss: 0.0662 - val_autoencoder_output_loss: 0.0203
# Epoch 915/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.0634 - autoencoder_output_loss: 0.0194 - val_loss: 0.0652 - val_autoencoder_output_loss: 0.0200
# Epoch 916/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.0632 - autoencoder_output_loss: 0.0193 - val_loss: 0.0654 - val_autoencoder_output_loss: 0.0202
# Epoch 917/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.0635 - autoencoder_output_loss: 0.0194 - val_loss: 0.0660 - val_autoencoder_output_loss: 0.0202
# Epoch 918/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.0632 - autoencoder_output_loss: 0.0193 - val_loss: 0.0657 - val_autoencoder_output_loss: 0.0200
# Epoch 919/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.0632 - autoencoder_output_loss: 0.0193 - val_loss: 0.0654 - val_autoencoder_output_loss: 0.0200
# Epoch 920/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.0631 - autoencoder_output_loss: 0.0193 - val_loss: 0.0649 - val_autoencoder_output_loss: 0.0198
# Epoch 921/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.0630 - autoencoder_output_loss: 0.0193 - val_loss: 0.0656 - val_autoencoder_output_loss: 0.0202
# Epoch 922/1000
# 7200/7200 [==============================] - 1s 102us/step - loss: 0.0633 - autoencoder_output_loss: 0.0194 - val_loss: 0.0663 - val_autoencoder_output_loss: 0.0202
# Epoch 923/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.0633 - autoencoder_output_loss: 0.0193 - val_loss: 0.0655 - val_autoencoder_output_loss: 0.0201
# Epoch 924/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.0637 - autoencoder_output_loss: 0.0195 - val_loss: 0.0653 - val_autoencoder_output_loss: 0.0200
# Epoch 925/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.0632 - autoencoder_output_loss: 0.0193 - val_loss: 0.0656 - val_autoencoder_output_loss: 0.0203
# Epoch 926/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.0631 - autoencoder_output_loss: 0.0193 - val_loss: 0.0657 - val_autoencoder_output_loss: 0.0204
# Epoch 927/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.0632 - autoencoder_output_loss: 0.0194 - val_loss: 0.0654 - val_autoencoder_output_loss: 0.0203
# Epoch 928/1000
# 7200/7200 [==============================] - 1s 101us/step - loss: 0.0631 - autoencoder_output_loss: 0.0193 - val_loss: 0.0654 - val_autoencoder_output_loss: 0.0202
# Epoch 929/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.0630 - autoencoder_output_loss: 0.0193 - val_loss: 0.0645 - val_autoencoder_output_loss: 0.0198
# Epoch 930/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.0631 - autoencoder_output_loss: 0.0193 - val_loss: 0.0660 - val_autoencoder_output_loss: 0.0202
# Epoch 931/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.0631 - autoencoder_output_loss: 0.0193 - val_loss: 0.0657 - val_autoencoder_output_loss: 0.0202
# Epoch 932/1000
# 7200/7200 [==============================] - 1s 111us/step - loss: 0.0632 - autoencoder_output_loss: 0.0193 - val_loss: 0.0652 - val_autoencoder_output_loss: 0.0202
# Epoch 933/1000
# 7200/7200 [==============================] - 1s 112us/step - loss: 0.0632 - autoencoder_output_loss: 0.0194 - val_loss: 0.0657 - val_autoencoder_output_loss: 0.0202
# Epoch 934/1000
# 7200/7200 [==============================] - 1s 108us/step - loss: 0.0632 - autoencoder_output_loss: 0.0194 - val_loss: 0.0659 - val_autoencoder_output_loss: 0.0201
# Epoch 935/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.0630 - autoencoder_output_loss: 0.0193 - val_loss: 0.0646 - val_autoencoder_output_loss: 0.0201
# Epoch 936/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.0633 - autoencoder_output_loss: 0.0194 - val_loss: 0.0656 - val_autoencoder_output_loss: 0.0203
# Epoch 937/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.0629 - autoencoder_output_loss: 0.0193 - val_loss: 0.0652 - val_autoencoder_output_loss: 0.0201
# Epoch 938/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.0631 - autoencoder_output_loss: 0.0193 - val_loss: 0.0647 - val_autoencoder_output_loss: 0.0200
# Epoch 939/1000
# 7200/7200 [==============================] - 1s 102us/step - loss: 0.0631 - autoencoder_output_loss: 0.0193 - val_loss: 0.0659 - val_autoencoder_output_loss: 0.0204
# Epoch 940/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.0634 - autoencoder_output_loss: 0.0194 - val_loss: 0.0652 - val_autoencoder_output_loss: 0.0200
# Epoch 941/1000
# 7200/7200 [==============================] - 1s 104us/step - loss: 0.0631 - autoencoder_output_loss: 0.0193 - val_loss: 0.0660 - val_autoencoder_output_loss: 0.0204
# Epoch 942/1000
# 7200/7200 [==============================] - 1s 101us/step - loss: 0.0631 - autoencoder_output_loss: 0.0194 - val_loss: 0.0650 - val_autoencoder_output_loss: 0.0200
# Epoch 943/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.0630 - autoencoder_output_loss: 0.0193 - val_loss: 0.0654 - val_autoencoder_output_loss: 0.0202
# Epoch 944/1000
# 7200/7200 [==============================] - 1s 123us/step - loss: 0.0632 - autoencoder_output_loss: 0.0194 - val_loss: 0.0651 - val_autoencoder_output_loss: 0.0200
# Epoch 945/1000
# 7200/7200 [==============================] - 1s 113us/step - loss: 0.0630 - autoencoder_output_loss: 0.0193 - val_loss: 0.0660 - val_autoencoder_output_loss: 0.0204
# Epoch 946/1000
# 7200/7200 [==============================] - 1s 105us/step - loss: 0.0631 - autoencoder_output_loss: 0.0193 - val_loss: 0.0649 - val_autoencoder_output_loss: 0.0200
# Epoch 947/1000
# 7200/7200 [==============================] - 1s 110us/step - loss: 0.0630 - autoencoder_output_loss: 0.0193 - val_loss: 0.0657 - val_autoencoder_output_loss: 0.0201
# Epoch 948/1000
# 7200/7200 [==============================] - 1s 109us/step - loss: 0.0631 - autoencoder_output_loss: 0.0193 - val_loss: 0.0652 - val_autoencoder_output_loss: 0.0202
# Epoch 949/1000
# 7200/7200 [==============================] - 1s 109us/step - loss: 0.0636 - autoencoder_output_loss: 0.0195 - val_loss: 0.0656 - val_autoencoder_output_loss: 0.0202
# Epoch 950/1000
# 7200/7200 [==============================] - 1s 115us/step - loss: 0.0629 - autoencoder_output_loss: 0.0193 - val_loss: 0.0645 - val_autoencoder_output_loss: 0.0200
# Epoch 951/1000
# 7200/7200 [==============================] - 1s 108us/step - loss: 0.0628 - autoencoder_output_loss: 0.0193 - val_loss: 0.0650 - val_autoencoder_output_loss: 0.0200
# Epoch 952/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.0631 - autoencoder_output_loss: 0.0194 - val_loss: 0.0651 - val_autoencoder_output_loss: 0.0201
# Epoch 953/1000
# 7200/7200 [==============================] - 1s 101us/step - loss: 0.0630 - autoencoder_output_loss: 0.0193 - val_loss: 0.0647 - val_autoencoder_output_loss: 0.0200
# Epoch 954/1000
# 7200/7200 [==============================] - 1s 107us/step - loss: 0.0632 - autoencoder_output_loss: 0.0194 - val_loss: 0.0651 - val_autoencoder_output_loss: 0.0199
# Epoch 955/1000
# 7200/7200 [==============================] - 1s 104us/step - loss: 0.0631 - autoencoder_output_loss: 0.0193 - val_loss: 0.0652 - val_autoencoder_output_loss: 0.0202
# Epoch 956/1000
# 7200/7200 [==============================] - 1s 113us/step - loss: 0.0629 - autoencoder_output_loss: 0.0193 - val_loss: 0.0644 - val_autoencoder_output_loss: 0.0200
# Epoch 957/1000
# 7200/7200 [==============================] - 1s 102us/step - loss: 0.0629 - autoencoder_output_loss: 0.0193 - val_loss: 0.0649 - val_autoencoder_output_loss: 0.0200
# Epoch 958/1000
# 7200/7200 [==============================] - 1s 96us/step - loss: 0.0628 - autoencoder_output_loss: 0.0193 - val_loss: 0.0648 - val_autoencoder_output_loss: 0.0199
# Epoch 959/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.0629 - autoencoder_output_loss: 0.0193 - val_loss: 0.0651 - val_autoencoder_output_loss: 0.0201
# Epoch 960/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.0638 - autoencoder_output_loss: 0.0196 - val_loss: 0.0660 - val_autoencoder_output_loss: 0.0205
# Epoch 961/1000
# 7200/7200 [==============================] - 1s 101us/step - loss: 0.0636 - autoencoder_output_loss: 0.0195 - val_loss: 0.0652 - val_autoencoder_output_loss: 0.0202
# Epoch 962/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.0635 - autoencoder_output_loss: 0.0195 - val_loss: 0.0671 - val_autoencoder_output_loss: 0.0205
# Epoch 963/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.0634 - autoencoder_output_loss: 0.0195 - val_loss: 0.0656 - val_autoencoder_output_loss: 0.0203
# Epoch 964/1000
# 7200/7200 [==============================] - 1s 107us/step - loss: 0.0633 - autoencoder_output_loss: 0.0194 - val_loss: 0.0650 - val_autoencoder_output_loss: 0.0201
# Epoch 965/1000
# 7200/7200 [==============================] - 1s 106us/step - loss: 0.0631 - autoencoder_output_loss: 0.0194 - val_loss: 0.0650 - val_autoencoder_output_loss: 0.0201
# Epoch 966/1000
# 7200/7200 [==============================] - 1s 105us/step - loss: 0.0633 - autoencoder_output_loss: 0.0194 - val_loss: 0.0659 - val_autoencoder_output_loss: 0.0204
# Epoch 967/1000
# 7200/7200 [==============================] - 1s 108us/step - loss: 0.0631 - autoencoder_output_loss: 0.0194 - val_loss: 0.0654 - val_autoencoder_output_loss: 0.0202
# Epoch 968/1000
# 7200/7200 [==============================] - 1s 112us/step - loss: 0.0633 - autoencoder_output_loss: 0.0194 - val_loss: 0.0651 - val_autoencoder_output_loss: 0.0200
# Epoch 969/1000
# 7200/7200 [==============================] - 1s 121us/step - loss: 0.0632 - autoencoder_output_loss: 0.0194 - val_loss: 0.0649 - val_autoencoder_output_loss: 0.0203
# Epoch 970/1000
# 7200/7200 [==============================] - 1s 114us/step - loss: 0.0630 - autoencoder_output_loss: 0.0194 - val_loss: 0.0653 - val_autoencoder_output_loss: 0.0201
# Epoch 971/1000
# 7200/7200 [==============================] - 1s 108us/step - loss: 0.0631 - autoencoder_output_loss: 0.0194 - val_loss: 0.0649 - val_autoencoder_output_loss: 0.0201
# Epoch 972/1000
# 7200/7200 [==============================] - 1s 107us/step - loss: 0.0631 - autoencoder_output_loss: 0.0194 - val_loss: 0.0665 - val_autoencoder_output_loss: 0.0205
# Epoch 973/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.0632 - autoencoder_output_loss: 0.0194 - val_loss: 0.0642 - val_autoencoder_output_loss: 0.0198
# Epoch 974/1000
# 7200/7200 [==============================] - 1s 102us/step - loss: 0.0631 - autoencoder_output_loss: 0.0194 - val_loss: 0.0666 - val_autoencoder_output_loss: 0.0206
# Epoch 975/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.0638 - autoencoder_output_loss: 0.0196 - val_loss: 0.0660 - val_autoencoder_output_loss: 0.0204
# Epoch 976/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.0630 - autoencoder_output_loss: 0.0194 - val_loss: 0.0659 - val_autoencoder_output_loss: 0.0204
# Epoch 977/1000
# 7200/7200 [==============================] - 1s 100us/step - loss: 0.0630 - autoencoder_output_loss: 0.0194 - val_loss: 0.0653 - val_autoencoder_output_loss: 0.0201
# Epoch 978/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.0631 - autoencoder_output_loss: 0.0194 - val_loss: 0.0647 - val_autoencoder_output_loss: 0.0200
# Epoch 979/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.0629 - autoencoder_output_loss: 0.0193 - val_loss: 0.0652 - val_autoencoder_output_loss: 0.0201
# Epoch 980/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.0631 - autoencoder_output_loss: 0.0194 - val_loss: 0.0650 - val_autoencoder_output_loss: 0.0201
# Epoch 981/1000
# 7200/7200 [==============================] - 1s 99us/step - loss: 0.0630 - autoencoder_output_loss: 0.0193 - val_loss: 0.0663 - val_autoencoder_output_loss: 0.0207
# Epoch 982/1000
# 7200/7200 [==============================] - 1s 98us/step - loss: 0.0631 - autoencoder_output_loss: 0.0194 - val_loss: 0.0649 - val_autoencoder_output_loss: 0.0201
# Epoch 983/1000
# 7200/7200 [==============================] - 1s 101us/step - loss: 0.0630 - autoencoder_output_loss: 0.0194 - val_loss: 0.0650 - val_autoencoder_output_loss: 0.0202
# Epoch 984/1000
# 7200/7200 [==============================] - 1s 105us/step - loss: 0.0630 - autoencoder_output_loss: 0.0194 - val_loss: 0.0647 - val_autoencoder_output_loss: 0.0201
# Epoch 985/1000
# 7200/7200 [==============================] - 1s 106us/step - loss: 0.0630 - autoencoder_output_loss: 0.0194 - val_loss: 0.0647 - val_autoencoder_output_loss: 0.0200
# Epoch 986/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.0629 - autoencoder_output_loss: 0.0193 - val_loss: 0.0649 - val_autoencoder_output_loss: 0.0200
# Epoch 987/1000
# 7200/7200 [==============================] - 1s 103us/step - loss: 0.0630 - autoencoder_output_loss: 0.0194 - val_loss: 0.0659 - val_autoencoder_output_loss: 0.0204
# Epoch 988/1000
# 7200/7200 [==============================] - 1s 101us/step - loss: 0.0637 - autoencoder_output_loss: 0.0196 - val_loss: 0.0657 - val_autoencoder_output_loss: 0.0202
# Epoch 989/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.0631 - autoencoder_output_loss: 0.0194 - val_loss: 0.0643 - val_autoencoder_output_loss: 0.0199
# Epoch 990/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.0629 - autoencoder_output_loss: 0.0193 - val_loss: 0.0649 - val_autoencoder_output_loss: 0.0199
# Epoch 991/1000
# 7200/7200 [==============================] - 1s 91us/step - loss: 0.0628 - autoencoder_output_loss: 0.0193 - val_loss: 0.0656 - val_autoencoder_output_loss: 0.0200
# Epoch 992/1000
# 7200/7200 [==============================] - 1s 91us/step - loss: 0.0629 - autoencoder_output_loss: 0.0193 - val_loss: 0.0651 - val_autoencoder_output_loss: 0.0202
# Epoch 993/1000
# 7200/7200 [==============================] - 1s 90us/step - loss: 0.0629 - autoencoder_output_loss: 0.0193 - val_loss: 0.0647 - val_autoencoder_output_loss: 0.0200
# Epoch 994/1000
# 7200/7200 [==============================] - 1s 92us/step - loss: 0.0628 - autoencoder_output_loss: 0.0193 - val_loss: 0.0658 - val_autoencoder_output_loss: 0.0205
# Epoch 995/1000
# 7200/7200 [==============================] - 1s 90us/step - loss: 0.0629 - autoencoder_output_loss: 0.0194 - val_loss: 0.0652 - val_autoencoder_output_loss: 0.0204
# Epoch 996/1000
# 7200/7200 [==============================] - 1s 96us/step - loss: 0.0629 - autoencoder_output_loss: 0.0194 - val_loss: 0.0659 - val_autoencoder_output_loss: 0.0205
# Epoch 997/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.0634 - autoencoder_output_loss: 0.0194 - val_loss: 0.0644 - val_autoencoder_output_loss: 0.0200
# Epoch 998/1000
# 7200/7200 [==============================] - 1s 97us/step - loss: 0.0630 - autoencoder_output_loss: 0.0193 - val_loss: 0.0650 - val_autoencoder_output_loss: 0.0201
# Epoch 999/1000
# 7200/7200 [==============================] - 1s 94us/step - loss: 0.0627 - autoencoder_output_loss: 0.0193 - val_loss: 0.0648 - val_autoencoder_output_loss: 0.0200
# Epoch 1000/1000
# 7200/7200 [==============================] - 1s 93us/step - loss: 0.0628 - autoencoder_output_loss: 0.0193 - val_loss: 0.0645 - val_autoencoder_output_loss: 0.0198
#
# Epoch 01000: saving model to ./log_weights/F_AE_50_weights.MNIST1000.hdf5

# %%
loss = F_AE_history.history['loss']
val_loss = F_AE_history.history['val_loss']

epochs = range(epochs_number)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(epochs[250:], loss[250:], 'bo', label='Training Loss')
plt.plot(epochs[250:], val_loss[250:], 'r', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
p_data=F_AE.predict(x_test)
numbers=x_test.shape[0]*x_test.shape[1]

print("MSE for one-to-one map layer",np.sum(np.power(np.array(p_data)[0]-x_test,2))/numbers)
print("MSE for feature selection layer",np.sum(np.power(np.array(p_data)[1]-x_test,2))/numbers)
# Out:
# MSE for one-to-one map layer 0.017872964664381378
# MSE for feature selection layer 0.01906917400749362

# %%
F.show_data_figures(p_data[0][0:160],w=28,h=28,columns = 20)

# %%
F.show_data_figures(p_data[1][0:160],w=28,h=28,columns = 20)

# %%
F.show_feature_selection('./log_weights/F_AE_'+str(key_feture_number)+'_weights.MNIST0200.hdf5',x_test,p_sample_number=160,p_key_number=key_feture_number)

# %%
F.show_feature_selection('./log_weights/F_AE_'+str(key_feture_number)+'_weights.MNIST0400.hdf5',x_test,p_sample_number=160,p_key_number=key_feture_number)

# %%
F.show_feature_selection('./log_weights/F_AE_'+str(key_feture_number)+'_weights.MNIST0600.hdf5',x_test,p_sample_number=160,p_key_number=key_feture_number)

# %%
F.show_feature_selection('./log_weights/F_AE_'+str(key_feture_number)+'_weights.MNIST0800.hdf5',x_test,p_sample_number=160,p_key_number=key_feture_number)

# %%
F.show_feature_selection('./log_weights/F_AE_'+str(key_feture_number)+'_weights.MNIST1000.hdf5',x_test,p_sample_number=160,p_key_number=key_feture_number)

# %% [markdown]
# ---
# ### 3.1.2 Feature selection layer output
# ---

# %%
FS_layer_output=feature_selection_output.predict(x_test)
F.show_data_figures(FS_layer_output[0:160],w=28,h=28,columns = 20)

print(np.sum(FS_layer_output[0]>0))
# Out:
# 21

# %% [markdown]
# ---
# ### 3.1.3 Key features show
# ---

# %%
# Gray
'''
key_features=F.top_k_keepWeights_1(F_AE.get_layer(index=1).get_weights()[0],key_feture_number)
plt.axis('off')
plt.imshow(key_features.reshape((28, 28)),plt.cm.gray)
print(np.sum(F_AE.get_layer(index=1).get_weights()[0]>0))
'''

# Red
key_features=F.top_k_keepWeights_1(F_AE.get_layer(index=1).get_weights()[0],key_feture_number)
key_features_=key_features.reshape((28, 28))

plt.axis('off')
canvas=np.zeros((28,28))
plt.imshow(canvas,plt.cm.gray)

for index_i in np.arange(key_features_.shape[0]):
    for index_j in np.arange(key_features_.shape[1]): 
        if key_features_[index_i,index_j]==1:
            plt.scatter(index_j,index_i,s=100,color='r',marker="s")
plt.tight_layout()
plt.show()
print(np.sum(F_AE.get_layer(index=1).get_weights()[0]>0))
print(np.sum(key_features>0))
# Out:
# 192
# 50

# %% [markdown]
# # 4 Classifying

# %% [markdown]
# ### 4.1. Extra Trees

# %%
train_feature=C_train_x
train_label=C_train_y
test_feature=C_test_x
test_label=C_test_y
p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.954
# Testing accuracy： 0.954
# (1.0, 0.954)

# %%
F.show_data_figures(C_test_x[0:160],w=28,h=28,columns = 20)

# %%
C_test_y[0:160]
# Out:
# array([3, 7, 0, 6, 4, 6, 6, 1, 1, 8, 8, 3, 7, 1, 5, 6, 5, 0, 6, 8, 4, 2,
#        6, 5, 4, 9, 8, 2, 6, 0, 2, 8, 6, 1, 1, 5, 9, 9, 1, 1, 1, 7, 6, 3,
#        1, 3, 9, 1, 1, 3, 6, 7, 0, 2, 4, 3, 6, 4, 2, 1, 8, 5, 5, 7, 7, 7,
#        1, 6, 4, 6, 6, 2, 9, 1, 6, 9, 4, 9, 8, 0, 7, 4, 1, 0, 2, 4, 3, 0,
#        1, 1, 6, 5, 5, 8, 7, 3, 4, 0, 5, 8, 6, 7, 4, 5, 3, 9, 5, 2, 3, 6,
#        0, 4, 1, 1, 9, 5, 7, 4, 6, 4, 5, 2, 8, 7, 1, 6, 3, 7, 4, 1, 0, 5,
#        8, 0, 1, 6, 5, 7, 7, 6, 9, 3, 2, 3, 5, 7, 0, 1, 1, 8, 2, 4, 9, 7,
#        4, 5, 7, 6, 1, 8], dtype=uint8)

# %%
print(np.sum(FS_layer_output[0]>0))
# Out:
# 21

# %%
row=np.where(key_features_>0)[0]
column=np.where(key_features_>0)[1]

selected_position_list=[]
for i in np.arange(key_feture_number):
    selected_position_list.append((row[i],column[i]))

# %% [markdown]
# ---
# #### 4.1.1. On Identity Selection layer
# ---
#
# a) with zeros

# %%
train_feature=feature_selection_output.predict(C_train_x)
print("train_feature>0: ",np.sum(train_feature[0]>0))
print(train_feature.shape)
train_label=C_train_y

test_feature=feature_selection_output.predict(C_test_x)
print("test_feature>0: ",np.sum(test_feature[0]>0))
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# train_feature>0:  33
# (8000, 784)
# test_feature>0:  21
# (2000, 784)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.917
# Testing accuracy： 0.917
# (1.0, 0.917)

# %%
F.show_data_figures(test_feature[0:160],w=28,h=28,columns = 20)

# %% [markdown]
# ---
#
# b) Sparse matrix

# %%
train_feature=feature_selection_output.predict(C_train_x)
print(train_feature.shape)
train_label=C_train_y

test_feature=feature_selection_output.predict(C_test_x)
print(test_feature.shape)
test_label=C_test_y

train_feature_sparse=sparse.coo_matrix(train_feature)
test_feature_sparse=sparse.coo_matrix(test_feature)

p_seed=seed
F.ETree(train_feature_sparse,train_label,test_feature_sparse,test_label,p_seed)
# Out:
# (8000, 784)
# (2000, 784)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.917
# Testing accuracy： 0.917
# (1.0, 0.917)

# %% [markdown]
# ---
#
# c) Compression

# %%
train_feature_=feature_selection_output.predict(C_train_x)
train_feature=F.compress_zero(train_feature_,key_feture_number)
print(train_feature.shape)
train_label=C_train_y

test_feature_=feature_selection_output.predict(C_test_x)
test_feature=F.compress_zero(test_feature_,key_feture_number)
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (8000, 50)
# (2000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.4255
# Testing accuracy： 0.4255
# (1.0, 0.4255)

# %% [markdown]
# ---
#
# d) Compression with structure

# %%
train_feature_=feature_selection_output.predict(C_train_x)
train_feature=F.compress_zero_withkeystructure(train_feature_,selected_position_list,w=28,h=28)
print(train_feature.shape)
train_label=C_train_y

test_feature_=feature_selection_output.predict(C_test_x)
test_feature=F.compress_zero_withkeystructure(test_feature_,selected_position_list,w=28,h=28)
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (8000, 50)
# (2000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9385
# Testing accuracy： 0.9385
# (1.0, 0.9385)

# %% [markdown]
# ---
# #### 4.1.2. On Original Selection
# ---
#
# a) with zeros

# %%
train_feature=np.multiply(C_train_x, key_features)
print("train_feature>0: ",np.sum(train_feature[0]>0))
print(train_feature.shape)
train_label=C_train_y

test_feature=np.multiply(C_test_x, key_features)
print("test_feature>0: ",np.sum(test_feature[0]>0))
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# train_feature>0:  33
# (8000, 784)
# test_feature>0:  21
# (2000, 784)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.917
# Testing accuracy： 0.917
# (1.0, 0.917)

# %%
F.show_data_figures(test_feature[0:160],w=28,h=28,columns = 20)

# %% [markdown]
# ---
#
# b) Sparse matrix

# %%
train_feature=np.multiply(C_train_x, key_features)
print(train_feature.shape)
train_label=C_train_y

test_feature=np.multiply(C_test_x, key_features)
print(test_feature.shape)
test_label=C_test_y

train_feature_sparse=sparse.coo_matrix(train_feature)
test_feature_sparse=sparse.coo_matrix(test_feature)

p_seed=seed
F.ETree(train_feature_sparse,train_label,test_feature_sparse,test_label,p_seed)
# Out:
# (8000, 784)
# (2000, 784)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.917
# Testing accuracy： 0.917
# (1.0, 0.917)

# %% [markdown]
# ---
#
# c) Compression

# %%
train_feature_=np.multiply(C_train_x, key_features)
train_feature=F.compress_zero(train_feature_,key_feture_number)
print(train_feature.shape)
train_label=C_train_y

test_feature_=np.multiply(C_test_x, key_features)
test_feature=F.compress_zero(test_feature_,key_feture_number)
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (8000, 50)
# (2000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.35
# Testing accuracy： 0.35
# (1.0, 0.35)

# %% [markdown]
# ---
#
# d) Compression with structure

# %%
train_feature_=np.multiply(C_train_x, key_features)
train_feature=F.compress_zero_withkeystructure(train_feature_,selected_position_list,w=28,h=28)
print(train_feature.shape)
train_label=C_train_y

test_feature_=np.multiply(C_test_x, key_features)
test_feature=F.compress_zero_withkeystructure(test_feature_,selected_position_list,w=28,h=28)
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (8000, 50)
# (2000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9385
# Testing accuracy： 0.9385
# (1.0, 0.9385)

# %% [markdown]
# ---
# #### 4.1.3. Latent space
# ---

# %%
train_feature=latent_encoder_score_F_AE.predict(C_train_x)
print(train_feature.shape)
train_label=C_train_y
test_feature=latent_encoder_score_F_AE.predict(C_test_x)
print(test_feature.shape)
test_label=C_test_y
p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (8000, 50)
# (2000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.911
# Testing accuracy： 0.911
# (1.0, 0.911)

# %%
train_feature=latent_encoder_choose_F_AE.predict(C_train_x)
print(train_feature.shape)
train_label=C_train_y
test_feature=latent_encoder_choose_F_AE.predict(C_test_x)
print(test_feature.shape)
test_label=C_test_y
p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (8000, 50)
# (2000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9035
# Testing accuracy： 0.9035
# (1.0, 0.9035)

# %% [markdown]
# ---
# # 5 Merge features
# ---

# %%
key_feature_catch_index=[]
for key_feature_catch_i in FS_layer_output[0:160]:
    key_feature_catch_i_=key_feature_catch_i.reshape(28,28)
    key_feature_catch_i_nonzeros_index=np.where(key_feature_catch_i_>0)
    key_feature_catch_i_nonzeros_index_pair=[]
    for i in np.arange(len(key_feature_catch_i_nonzeros_index[0])):
        key_feature_catch_i_nonzeros_index_pair.append([key_feature_catch_i_nonzeros_index[0][i],key_feature_catch_i_nonzeros_index[1][i]])
    key_feature_catch_index.append(key_feature_catch_i_nonzeros_index_pair)

# %%
F.show_data_figures_with_hierarchy_keyfeature(x_test[0:160],key_feature_catch_index,w=28,h=28,columns = 20)

# %% [markdown]
# ---
# # 6 Feature group compare
#
# ---

# %%
Selected_Weights=F.top_k_keep(F_AE.get_layer(index=1).get_weights()[0],key_feture_number)

# %%
print(np.sum(Selected_Weights>0))

Selected_Weights_=Selected_Weights.reshape((28, 28))

print(len(np.unique(Selected_Weights_)))

selected_position_for_group=F.k_index_argsort(Selected_Weights_,key_feture_number)
selected_position_group=[tuple(i) for i in selected_position_for_group]
# Out:
# 50
# 51

# %%
train_feature_=np.multiply(C_train_x, key_features)
train_feature=F.compress_zero_withkeystructure(train_feature_,selected_position_group,w=28,h=28)
print(train_feature.shape)
train_label=C_train_y

test_feature_=np.multiply(C_test_x, key_features)
test_feature=F.compress_zero_withkeystructure(test_feature_,selected_position_group,w=28,h=28)
print(test_feature.shape)
test_label=C_test_y
# Out:
# (8000, 50)
# (2000, 50)

# %%
p_seed=seed
F.ETree(train_feature[:,0:25],train_label,test_feature[:,0:25],test_label,p_seed)
# Out:
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.8735
# Testing accuracy： 0.8735
# (1.0, 0.8735)

# %%
p_seed=seed
F.ETree(train_feature[:,25:],train_label,test_feature[:,25:],test_label,p_seed)
# Out:
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.858
# Testing accuracy： 0.858
# (1.0, 0.858)

# %%
p_seed=seed
F.ETree(train_feature[:,0:30],train_label,test_feature[:,0:30],test_label,p_seed)
# Out:
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9025
# Testing accuracy： 0.9025
# (1.0, 0.9025)

# %%
p_seed=seed
F.ETree(train_feature[:,30:],train_label,test_feature[:,30:],test_label,p_seed)
# Out:
# Training accuracy： 0.999875
# Training accuracy： 0.999875
# Testing accuracy： 0.8295
# Testing accuracy： 0.8295
# (0.999875, 0.8295)

# %% [markdown]
# # 7. Reconstruction loss

# %%
from sklearn.linear_model import LinearRegression

def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR

# %%
train_feature_=np.multiply(C_train_x, key_features)
C_train_selected_x=F.compress_zero_withkeystructure(train_feature_,selected_position_list)
print(C_train_selected_x.shape)

test_feature_=np.multiply(C_test_x, key_features)
C_test_selected_x=F.compress_zero_withkeystructure(test_feature_,selected_position_list)
print(C_test_selected_x.shape)


train_feature_tuple=(C_train_selected_x,C_train_x)
test_feature_tuple=(C_test_selected_x,C_test_x)

reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
print(reconstruction_loss)
# Out:
# (8000, 50)
# (2000, 50)
# 0.018246043775591782
